# %% [markdown]
# # PyLAR
# ## [Python utilities for the LAR model](https://github.com/seap-udea/pylar)

# %% [markdown]
# ## Quickstart
# <a target="_blank" href="https://colab.research.google.com/github/seap-udea/pylar/blob/main/tutorials/pylar-quickstart.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ### Before start

# %% [markdown]
# If you are using `Google Colab` you must execute this cell first:

# %%
import sys
if 'google.colab' in sys.modules:
    # !sudo pip install -Uq ipylar

# %% [markdown]
# Import `PyLAR`

# %%
import ipylar as lar
# %load_ext autoreload 
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# > **NOTE**: The *magic commands* `%load_ext` y `%autoreload` are only necessary during the development of this notebook. You may remove it when developing your own notebooks.

# %% [markdown]
# ### Creating a Basin

# %% [markdown]
# You may create a basin:

# %%
amazonas = lar.Basin(key='amazonas',name='Amazonas')

# %% [markdown]
# Basin objects are basically data structures:

# %%
amazonas.__dict__
# Out:
# {'key': 'amazonas',
#  'name': 'Amazonas',
#  'data': Empty DataFrame
#  Columns: [datestd, datetime, time, R, dR, nq, dnq, Rref, nqref]
#  Index: []}

# %% [markdown]
# For some basins, `PyLAR` provides sample data that can be used for demonstration purposes:

# %%
amazonas.read_basin_data()
# Out:
# ****************************************
# amazonas
# Number of data points: merge = 493, total = 493
# Initial time: 285310800.0
# Initial date: 1979-01-16 00:00:00
# Total data points: 493
# Time span: 40.99931553730322 a = 14975.0 d
# Signal correlation (R - nq): -0.058486683234719256

# %%
amazonas.read_basin_data(rsource=['hybam','xlsx','V4'])
# Out:
# ****************************************
# amazonas
# Number of data points: merge = 492, total = 492
# Initial time: 285310800.0
# Initial date: 1979-01-16 00:00:00
# Total data points: 492
# Time span: 40.91444216290212 a = 14944.0 d
# Signal correlation (R - nq): -0.091294406770398

# %% [markdown]
# Once loaded you may plot the time-series of the convergence and discharge data series:

# %%
fig = amazonas.plot_basin_series()

# %%
fig = amazonas.plot_basin_series()

# %%
fig.savefig('resources/amazonas-lar-timeseries.png')

# %% [markdown]
# ### Sample data

# %% [markdown]
# `PyLAR` comes with sample data for six large river basins. You may list data files available using:

# %%
lar.list_data()
# Out:
# ['yenisei_grace_gsfc.csv',
#  'RQ_era5_readme.txt',
#  'yenisei_RQ_era5.csv',
#  'ob_divQ_era5.csv',
#  'yenisei_grace_utexas.csv',
#  'amazonas_grace_gsfc.csv',
#  'yenisei_divQ_era5.csv',
#  'parana_divQ_era5.csv',
#  'mississippi_grace_utexas.csv',
#  'congo_grace_utexas.csv',
#  'parana_RQ_era5.csv',
#  'amazonas_grace_utexas.csv',
#  'parana_grace_utexas.csv',
#  'amazonas_divQ_era5.csv',
#  'mississippi_grace_gsfc.csv',
#  'ob_grace_utexas.csv',
#  'mississippi_divQ_era5.csv',
#  'congo_grace_gsfc.csv',
#  'amazonas_RQ_era5.csv',
#  'congo_divQ_era5.csv',
#  'congo_RQ_era5.csv',
#  'ob_grace_gsfc.csv',
#  'magdalena_output.csv',
#  'ob_RQ_era5.csv',
#  'mississippi_RQ_era5.csv',
#  'parana_grace_gsfc.csv',
#  'amazonas_R_hybam.xlsx']

# %%
import pandas as pd
pd.read_csv(lar.get_data_path('amazonas_RQ_era5.csv'))
# Out:
#            date     water_vap      water_liq      water_ice          prec  \
# 0    1979-01-01  1.649144e+08  -31505.250744 -415274.821138  3.525267e+08
# 1    1979-02-01  1.679767e+08  287063.293632 -349791.940767  3.637470e+08
# 2    1979-03-01  3.540050e+08  658490.206339 -712085.067386  5.271912e+08
# 3    1979-04-01  2.779652e+08  156146.053462 -529287.188635  4.649235e+08
# 4    1979-05-01  2.106166e+08 -268475.512116 -242763.541722  3.906757e+08
# ..          ...           ...            ...            ...           ...
# 499  2020-08-01 -8.895706e+06 -786197.840338  -62543.467188  1.300764e+08
# 500  2020-09-01  3.611787e+07 -559272.310862 -196240.243603  1.928426e+08
# 501  2020-10-01  8.215583e+07  -94334.046645 -270202.736175  2.306606e+08
# 502  2020-11-01  1.849516e+08   69000.435167 -426092.222199  3.672909e+08
# 503  2020-12-01  3.114779e+08  163752.672099 -754007.179872  5.005159e+08
#
#              evap     temp_2m      dew_2m    lai_lv    lai_hv   discharge
# 0   -2.079831e+08  297.338324  294.394680  1.132965  4.644195  154457.742
# 1   -2.053666e+08  297.418068  294.365114  1.134655  4.585946  168767.933
# 2   -1.898632e+08  296.813609  294.695153  1.137469  4.551175  181792.971
# 3   -1.823338e+08  296.477926  294.195753  1.142775  4.604890  204447.827
# 4   -1.704876e+08  296.332156  294.095950  1.141098  4.685922  221537.347
# ..            ...         ...         ...       ...       ...         ...
# 499 -1.772483e+08  297.497186  291.973514  1.152528  5.585907         NaN
# 500 -2.026149e+08  298.330914  293.391206  1.156350  5.648177         NaN
# 501 -2.117251e+08  298.643934  294.040812  1.154401  5.360792         NaN
# 502 -2.095597e+08  298.317542  294.531474  1.149658  5.098421         NaN
# 503 -2.018729e+08  297.556984  294.839269  1.134020  4.715265         NaN
#
# [504 rows x 11 columns]

# %% [markdown]
# <hr/>

# %% [markdown]
# For more examples and tutorials of `PyLAR` see the [GitHub repository](https://github.com/seap-udea/pylar/tree/main/tutorials)
